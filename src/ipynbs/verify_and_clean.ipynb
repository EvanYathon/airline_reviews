# %% [markdown]
# This notebook will load the scraped data, verify that all of the reviews scraped are in the original dataset, and then clean up the columns for use in analyis later.

# %%
# loading packages

# utils
import pandas as pd
import time
import numpy as np

# plotting
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# ensure the dates are parsed correctly with parse_dates argument
'reviews = pd.read_csv("../../data/scraped_gw_reviews.csv", parse_dates = ["date_of_review", "date_flown"])

# %%
reviews.head(50)
# Out:
#                                                 title  review_value  \
# 0                 "Seat was fine with enough legroom"           7.0
# 1                        "crew were smiling and good"           6.0
# 2                         "only two agents available"           1.0
# 3                    "good flight and friendly staff"           7.0
# 4                       "never been treated as badly"           1.0
# 5                                      "very cramped"           6.0
# 6                               "staff were friendly"          10.0
# 7                           PLEASE REFER TO EUROWINGS           NaN
# 8                             "great value for money"           8.0
# 9                             "pay very little money"           2.0
# 10                        "friendly and professional"           8.0
# 11                         "little choice of airline"           5.0
# 12                              "were very satisfied"          10.0
# 13                                 "no info or staff"           2.0
# 14                    "cabin crew were very friendly"           7.0
# 15                          "professional cabin crew"           9.0
# 16                             "friendly cabin staff"           8.0
# 17                      "they have been unresponsive"           2.0
# 18                       "impressed with Germanwings"           9.0
# 19                         "I was refused some water"           3.0
# 20  "the service crew were friendly but nothing more"           3.0
# 21       "no problems or delays, very friendly staff"          10.0
# 22       "I don't get why Germanwings is always late"           4.0
# 23           "vowing never to book Germanwings again"           1.0
# 24                   "staff friendly - food terrible"           7.0
# 25               "no explanations, no offers of help"           2.0
# 26             "delay in Heathrow about 1:30 minutes"           2.0
# 27                        Germanwings customer review           5.0
# 28                        Germanwings customer review           2.0
# 29                        Germanwings customer review          10.0
# 30                        Germanwings customer review           1.0
# 31                        Germanwings customer review           2.0
# 32                        Germanwings customer review           7.0
# 33                        Germanwings customer review           7.0
# 34                        Germanwings customer review           9.0
# 35                        Germanwings customer review           2.0
# 36                        Germanwings customer review           4.0
# 37                        Germanwings customer review           7.0
# 38                        Germanwings customer review           8.0
# 39                        Germanwings customer review          10.0
# 40                        Germanwings customer review           2.0
# 41                        Germanwings customer review           9.0
# 42                        Germanwings customer review           7.0
# 43                        Germanwings customer review           8.0
# 44                        Germanwings customer review           8.0
# 45                        Germanwings customer review           2.0
# 46                        Germanwings customer review          10.0
# 47                        Germanwings customer review           2.0
# 48                        Germanwings customer review          10.0
# 49                        Germanwings customer review           NaN
#
#    n_user_reviews             reviewer_name  \
# 0       8 reviews            Sander van Kan
# 1       8 reviews            Sander van Kan
# 2       6 reviews           Andrew Maynard
# 3       1 reviews                   T Steen
# 4             NaN              Karen Kirner
# 5       8 reviews                 Mark West
# 6             NaN                   S Lueth
# 7             NaN            SKYTRAX Editor
# 8       5 reviews          Szymon Opaliński
# 9             NaN                   V Cozzi
# 10      2 reviews            R Schouwenberg
# 11            NaN                 J Tydeman
# 12     18 reviews            H Oberbeckmann
# 13            NaN                    Y Wong
# 14      2 reviews               John Hamill
# 15            NaN                  O Driver
# 16      2 reviews                 Dan Allen
# 17            NaN             Brian McNamee
# 18      6 reviews           Joseph Goodrich
# 19            NaN              L Mouratidou
# 20      4 reviews               H Mutschler
# 21            NaN            Oliver Numrich
# 22      1 reviews  Andreas Huettenhoelscher
# 23            NaN                  L Turner
# 24            NaN               Jay  Martin
# 25            NaN             Jacky Russell
# 26            NaN          Ralf-Peter Weber
# 27      4 reviews             Andrew Jerome
# 28            NaN             Nigel Goodman
# 29      1 reviews             Nigel Tansley
# 30            NaN                 R Schulze
# 31            NaN                  H Skopek
# 32            NaN                  B Diener
# 33            NaN      Eelco van den Heuvel
# 34            NaN               H Mutschler
# 35            NaN                  J Eggers
# 36            NaN               H Mutschler
# 37            NaN              Giacomo Cama
# 38            NaN                   M Tobin
# 39            NaN                 J Tinning
# 40            NaN                  M Bracey
# 41            NaN             R Brandenburg
# 42            NaN               Robert Wolf
# 43            NaN                Tony Quinn
# 44            NaN                  C Miller
# 45            NaN          Johannes Meunier
# 46            NaN            Eunice Cranmer
# 47            NaN                   J Prust
# 48            NaN                Ameil Paul
# 49            NaN                   A Firth
#
#                                      reviewer_country date_of_review  \
# 0   \n\n8 reviews\n\n\n\nSander van Kan (Netherlan...     2019-07-01
# 1   \n\n8 reviews\n\n\n\nSander van Kan (Netherlan...     2019-07-01
# 2   \n\n6 reviews\n\n\n\nAndrew Maynard  (United K...     2017-01-04
# 3   \n\n1 reviews\n\n\n\nT Steen (Netherlands) 13t...     2016-09-13
# 4         \n\nKaren Kirner (Austria) 16th August 2016     2016-08-16
# 5   \n\n8 reviews\n\n\n\nMark West (United Kingdom...     2016-05-11
# 6               \n\nS Lueth (Germany) 11th April 2016     2016-04-11
# 7   \n\nSKYTRAX Editor (United Kingdom) 8th Februa...     2016-02-08
# 8   \n\n5 reviews\n\n\n\nSzymon Opaliński (Spain) ...     2016-01-23
# 9      \n\nV Cozzi (United Kingdom) 21st January 2016     2016-01-21
# 10  \n\n2 reviews\n\n\n\nR Schouwenberg (Netherlan...     2015-12-22
# 11   \n\nJ Tydeman (United Kingdom) 7th December 2015     2015-12-07
# 12  \n\n18 reviews\n\n\n\nH Oberbeckmann (Germany)...     2015-11-16
# 13               \n\nY Wong (Japan) 3rd November 2015     2015-11-03
# 14  \n\n2 reviews\n\n\n\nJohn Hamill (Ireland) 27t...     2015-10-27
# 15           \n\nO Driver (Germany) 21st October 2015     2015-10-21
# 16  \n\n2 reviews\n\n\n\nDan Allen (United Kingdom...     2015-10-21
# 17       \n\nBrian McNamee (Canada) 16th October 2015     2015-10-16
# 18  \n\n6 reviews\n\n\n\nJoseph Goodrich (United S...     2015-10-15
# 19  \n\nL Mouratidou (United Kingdom) 4th October ...     2015-10-04
# 20  \n\n4 reviews\n\n\n\nH Mutschler (Germany) 21s...     2015-09-21
# 21   \n\nOliver Numrich (Germany) 20th September 2015     2015-09-20
# 22  \n\n1 reviews\n\n\n\nAndreas Huettenhoelscher ...     2015-09-14
# 23   \n\nL Turner (United Kingdom) 9th September 2015     2015-09-09
# 24       \n\nJay  Martin (Germany) 9th September 2015     2015-09-09
# 25  \n\nJacky Russell (United Kingdom) 6th Septemb...     2015-09-06
# 26  \n\nRalf-Peter Weber (Gibraltar) 31st August 2015     2015-08-31
# 27  \n\n4 reviews\n\n\n\nAndrew Jerome (Australia)...     2015-08-25
# 28       \n\nNigel Goodman (Germany) 15th August 2015     2015-08-15
# 29  \n\n1 reviews\n\n\n\nNigel Tansley (United Kin...     2015-07-30
# 30              \n\nR Schulze (Germany) 2nd July 2015     2015-07-02
# 31        \n\nH Skopek (United States) 19th June 2015     2015-06-19
# 32        \n\nB Diener (Czech Republic) 31st May 2015     2015-05-31
# 33  \n\nEelco van den Heuvel (Netherlands) 28th Ma...     2015-05-28
# 34            \n\nH Mutschler (Germany) 22nd May 2015     2015-05-22
# 35                \n\nJ Eggers (Germany) 8th May 2015     2015-05-08
# 36             \n\nH Mutschler (Germany) 1st May 2015     2015-05-01
# 37        \n\nGiacomo Cama (Italy) 24th February 2015     2015-02-24
# 38             \n\nM Tobin (Canada) 26th January 2015     2015-01-26
# 39           \n\nJ Tinning (Austria) 5th January 2015     2015-01-05
# 40     \n\nM Bracey (United Kingdom) 5th January 2015     2015-01-05
# 41     \n\nR Brandenburg (Germany) 31st December 2014     2014-12-31
# 42  \n\nRobert Wolf (United Kingdom) 22nd December...     2014-12-22
# 43  \n\nTony Quinn (United Kingdom) 22nd December ...     2014-12-22
# 44          \n\nC Miller (Germany) 18th December 2014     2014-12-18
# 45   \n\nJohannes Meunier (Germany) 6th November 2014     2014-11-06
# 46  \n\nEunice Cranmer (United Kingdom) 3rd Novemb...     2014-11-03
# 47          \n\nJ Prust (Germany) 27th September 2014     2014-09-27
# 48  \n\nAmeil Paul (United Kingdom) 17th September...     2014-09-17
# 49    \n\nA Firth (United Kingdom) 9th September 2014     2014-09-09
#
#                                           review_text     aircraft  \
# 0   ✅ Trip Verified | Dusseldorf to Berlin. Eurowi...         A319
# 1   ✅ Trip Verified | Berlin to Dusseldorf. Eurowi...         A319
# 2   Check in process at Cologne very poor. Flight ...          NaN
# 3   ✅ Verified Review |  Amsterdam to Stuttgart. G...          NaN
# 4   ✅ Verified Review |  I have been a frequent tr...          NaN
# 5   ✅ Verified Review |  Flew Germanwings from Lon...         A319
# 6   My boyfriend and I booked the basic fare from ...          NaN
# 7   Germanwings operations have now been transferr...          NaN
# 8   Lufthansa operated by Germanwings from Barcelo...  A320 / A319
# 9   Germanwings from Bangkok to London via Cologne...         A330
# 10  Germanwings flight from Berlin Tegel to Dussel...         A319
# 11  Not a bad price but little choice of airline a...          NaN
# 12  We have been flying Dortmund to Munich return ...         A319
# 13  Bad arrangements if outside the protocol. Ther...          NaN
# 14  Flew from Dublin to Rome via Cologne on German...         A319
# 15  Flying Germanwings "Best" section on domestic ...         A320
# 16  Hannover to Rome. At the airport we had a very...         A320
# 17  We flew with Germanwings (or tried to) on Sept...          NaN
# 18  Very impressed with Germanwings. The flight wa...         A319
# 19  I am less than impressed with Germanwings serv...          NaN
# 20  Flew from Palma de Mallorca to Cologne with Ge...     A319-100
# 21  Good flight from Berlin-Tegel to London Heathr...          NaN
# 22  I don't get why Germanwings is always late and...          NaN
# 23  We were delayed 5 hours in Istanbul and receiv...          NaN
# 24  Easy Check-In at Düsseldorf. The Germanwings f...          NaN
# 25  Checked in at Dusseldorf for our Germanwings f...          NaN
# 26  This Germanwings flight should take off as sch...         A320
# 27  Germanwings is a very mediocre airline. Compar...          NaN
# 28  I am Senator on Lufthansa so I fly a lot. Flyi...          NaN
# 29  Flight on time, booked smart fare which gave E...         A320
# 30  The flight was delayed by 6 hours, allegedly b...         A319
# 31  My wife and I were checking in our luggage  fo...          NaN
# 32  4U7779 and 4U7778 May16 and May 26 PRG-HAM-PRG...          NaN
# 33  DUS-GVA-DUS. Operated by Eurowings on CRJ 900....          NaN
# 34  Flew Best Class from Hamburg to Cologne. Best ...          NaN
# 35  Germanwings 9038 DUS-HAM May 6 yet another del...          NaN
# 36  CGN to HAM Airbus 320. Booked economy class I ...          NaN
# 37  I flew from Bologna to Berlin in February with...          NaN
# 38  DUS-PRG. Best value for your $$ when it comes ...          NaN
# 39  13th December from Heathrow T2 to Vienna via C...          NaN
# 40  LHR-Berlin 29 December - an hour late leaving ...          NaN
# 41  Just one hop from Berlin TXL to Paris CDG on e...          NaN
# 42  Flew at the end of October from London via Dus...          NaN
# 43  LHR-STR-LHR. First time using GW and was quite...          NaN
# 44  Regular on HAM-BHX which is Germanwings operat...          NaN
# 45  Flight Stuttgart-Hamburg. Was regular user of ...          NaN
# 46  Went with Germanwings from Manchester to Colog...          NaN
# 47  Cologne/Bonn to Manchester and return. Both le...          NaN
# 48  Flew London Heathrow - Cologne Bonn on Monday ...          NaN
# 49  I am writing this on behalf of my wife who is ...          NaN
#
#     traveller_type       seat_type                            route  \
# 0   Couple Leisure   Economy Class             Dusseldorf to Berlin
# 1   Couple Leisure   Economy Class             Berlin to Dusseldorf
# 2   Couple Leisure   Economy Class                       CGN to MAN
# 3         Business   Economy Class                       AMS to STR
# 4         Business   Economy Class                       DUS to VIE
# 5         Business   Economy Class                       STN to CGN
# 6   Couple Leisure   Economy Class                       HAM to FCO
# 7              NaN             NaN                              NaN
# 8     Solo Leisure   Economy Class                       BCN to TXL
# 9   Couple Leisure   Economy Class               BKK to LHR via CGN
# 10    Solo Leisure   Economy Class                       TXL to DUS
# 11  Family Leisure   Economy Class              Heathrow to Cologne
# 12  Couple Leisure   Economy Class                       DTM to MUC
# 13        Business   Economy Class                 London to Berlin
# 14  Couple Leisure   Economy Class       Dublin to Rome via Cologne
# 15        Business  Business Class                       TXL to DUS
# 16  Family Leisure   Economy Class                 Hannover to Rome
# 17  Couple Leisure   Economy Class           Stuttgart to Amsterdam
# 18    Solo Leisure   Economy Class                       KRK to STR
# 19    Solo Leisure   Economy Class                Hamburg to London
# 20  Couple Leisure   Economy Class                       PMI to CGN
# 21        Business             NaN  Berlin-Tegel to London Heathrow
# 22        Business   Economy Class                       CGN to LHR
# 23  Couple Leisure   Economy Class       Istanbul to London via DUS
# 24    Solo Leisure   Economy Class             Düsseldorf to London
# 25  Family Leisure   Economy Class           Dusseldorf to Heathrow
# 26        Business   Economy Class          Duesseldorf to Heathrow
# 27  Couple Leisure   Economy Class                 Cologne to Palma
# 28        Business   Economy Class                 Hamburg to Paris
# 29  Family Leisure   Economy Class              Stansted to Cologne
# 30        Business     First Class                       FCO to TXL
# 31  Couple Leisure   Economy Class                Hamburg to Geneva
# 32             NaN   Economy Class                              NaN
# 33             NaN   Economy Class                              NaN
# 34             NaN   Economy Class                              NaN
# 35             NaN   Economy Class                              NaN
# 36             NaN   Economy Class                              NaN
# 37             NaN   Economy Class                              NaN
# 38             NaN   Economy Class                              NaN
# 39             NaN   Economy Class                              NaN
# 40             NaN   Economy Class                              NaN
# 41             NaN   Economy Class                              NaN
# 42             NaN   Economy Class                              NaN
# 43             NaN   Economy Class                              NaN
# 44             NaN   Economy Class                              NaN
# 45             NaN   Economy Class                              NaN
# 46             NaN   Economy Class                              NaN
# 47             NaN   Economy Class                              NaN
# 48             NaN   Economy Class                              NaN
# 49             NaN   Economy Class                              NaN
#
#    date_flown  seat_comfort_rating  cabin_staff_service_rating  \
# 0  2019-06-01                  4.0                         3.0
# 1  2019-06-01                  3.0                         3.0
# 2  2017-01-01                  2.0                         2.0
# 3  2016-09-01                  5.0                         5.0
# 4  2016-08-01                  1.0                         1.0
# 5  2016-04-01                  1.0                         3.0
# 6  2015-05-01                  4.0                         5.0
# 7         NaT                  NaN                         NaN
# 8  2016-01-01                  5.0                         5.0
# 9  2016-01-01                  2.0                         2.0
# 10 2015-12-01                  4.0                         5.0
# 11 2015-12-01                  3.0                         3.0
# 12 2015-11-01                  5.0                         5.0
# 13 2015-11-01                  1.0                         2.0
# 14 2015-07-01                  4.0                         5.0
# 15 2015-10-01                  5.0                         4.0
# 16 2015-03-01                  4.0                         5.0
# 17 2015-09-01                  1.0                         1.0
# 18 2015-07-01                  4.0                         4.0
# 19 2015-09-01                  2.0                         1.0
# 20 2015-09-01                  3.0                         1.0
# 21 2015-08-01                  4.0                         5.0
# 22 2015-09-01                  3.0                         4.0
# 23 2015-09-01                  2.0                         2.0
# 24 2015-08-01                  3.0                         3.0
# 25 2015-09-01                  2.0                         2.0
# 26 2015-07-01                  3.0                         1.0
# 27 2015-08-01                  3.0                         3.0
# 28 2015-08-01                  3.0                         2.0
# 29 2015-07-01                  5.0                         5.0
# 30 2015-05-01                  2.0                         2.0
# 31 2015-06-01                  1.0                         1.0
# 32        NaT                  3.0                         2.0
# 33        NaT                  4.0                         4.0
# 34        NaT                  5.0                         5.0
# 35        NaT                  2.0                         1.0
# 36        NaT                  3.0                         2.0
# 37        NaT                  3.0                         5.0
# 38        NaT                  4.0                         5.0
# 39        NaT                  5.0                         5.0
# 40        NaT                  1.0                         1.0
# 41        NaT                  4.0                         5.0
# 42        NaT                  3.0                         3.0
# 43        NaT                  4.0                         4.0
# 44        NaT                  4.0                         3.0
# 45        NaT                  3.0                         2.0
# 46        NaT                  5.0                         5.0
# 47        NaT                  4.0                         2.0
# 48        NaT                  4.0                         3.0
# 49        NaT                  3.0                         2.0
#
#     food_and_beverages_rating  inflight_entertainment_rating  \
# 0                         NaN                            1.0
# 1                         NaN                            1.0
# 2                         NaN                            NaN
# 3                         1.0                            NaN
# 4                         NaN                            NaN
# 5                         2.0                            NaN
# 6                         5.0                            NaN
# 7                         NaN                            NaN
# 8                         3.0                            NaN
# 9                         1.0                            2.0
# 10                        3.0                            1.0
# 11                        1.0                            NaN
# 12                        5.0                            NaN
# 13                        2.0                            NaN
# 14                        4.0                            NaN
# 15                        5.0                            NaN
# 16                        2.0                            NaN
# 17                        NaN                            NaN
# 18                        4.0                            NaN
# 19                        NaN                            NaN
# 20                        1.0                            1.0
# 21                        4.0                            1.0
# 22                        2.0                            NaN
# 23                        1.0                            NaN
# 24                        1.0                            1.0
# 25                        1.0                            1.0
# 26                        1.0                            NaN
# 27                        1.0                            NaN
# 28                        1.0                            NaN
# 29                        4.0                            NaN
# 30                        1.0                            1.0
# 31                        NaN                            NaN
# 32                        0.0                            1.0
# 33                        4.0                            1.0
# 34                        4.0                            1.0
# 35                        1.0                            1.0
# 36                        0.0                            0.0
# 37                        2.0                            1.0
# 38                        0.0                            0.0
# 39                        3.0                            4.0
# 40                        3.0                            0.0
# 41                        4.0                            3.0
# 42                        1.0                            1.0
# 43                        2.0                            0.0
# 44                        4.0                            3.0
# 45                        2.0                            0.0
# 46                        5.0                            0.0
# 47                        2.0                            0.0
# 48                        2.0                            1.0
# 49                        1.0                            0.0
#
#     ground_service_rating  value_for_money_rating recommendation
# 0                     3.0                     5.0            yes
# 1                     3.0                     5.0            yes
# 2                     1.0                     2.0             no
# 3                     5.0                     5.0            yes
# 4                     3.0                     1.0             no
# 5                     2.0                     3.0            yes
# 6                     4.0                     5.0            yes
# 7                     NaN                     NaN            yes
# 8                     4.0                     5.0            yes
# 9                     1.0                     1.0             no
# 10                    3.0                     3.0            yes
# 11                    3.0                     3.0            yes
# 12                    5.0                     5.0            yes
# 13                    2.0                     1.0             no
# 14                    4.0                     4.0            yes
# 15                    4.0                     4.0            yes
# 16                    3.0                     4.0            yes
# 17                    1.0                     2.0             no
# 18                    4.0                     5.0            yes
# 19                    3.0                     2.0             no
# 20                    2.0                     1.0             no
# 21                    5.0                     4.0            yes
# 22                    1.0                     3.0             no
# 23                    1.0                     1.0             no
# 24                    4.0                     4.0            yes
# 25                    1.0                     1.0             no
# 26                    1.0                     2.0             no
# 27                    3.0                     5.0             no
# 28                    2.0                     2.0             no
# 29                    5.0                     5.0            yes
# 30                    1.0                     1.0             no
# 31                    1.0                     1.0             no
# 32                    NaN                     5.0            yes
# 33                    NaN                     4.0            yes
# 34                    NaN                     4.0            yes
# 35                    NaN                     2.0             no
# 36                    NaN                     3.0             no
# 37                    NaN                     3.0            yes
# 38                    NaN                     5.0            yes
# 39                    NaN                     5.0            yes
# 40                    NaN                     3.0             no
# 41                    NaN                     5.0            yes
# 42                    NaN                     3.0            yes
# 43                    NaN                     5.0            yes
# 44                    NaN                     5.0            yes
# 45                    NaN                     1.0             no
# 46                    NaN                     5.0            yes
# 47                    NaN                     2.0             no
# 48                    NaN                     4.0            yes
# 49                    NaN                     2.0             no

# %%
# check what column types we are working with
reviews.dtypes
# Out:
# title                                    object
# review_value                            float64
# n_user_reviews                           object
# reviewer_name                            object
# reviewer_country                         object
# date_of_review                   datetime64[ns]
# review_text                              object
# aircraft                                 object
# traveller_type                           object
# seat_type                                object
# route                                    object
# date_flown                       datetime64[ns]
# seat_comfort_rating                     float64
# cabin_staff_service_rating              float64
# food_and_beverages_rating               float64
# inflight_entertainment_rating           float64
# ground_service_rating                   float64
# value_for_money_rating                  float64
# recommendation                           object
# dtype: object

# %%
# check to see how many missing values there are for each column
print("Percentage of missing values for each column: \n")
(reviews.isna().sum()/reviews.shape[0])*100
# Out:
# Percentage of missing values for each column:
# title                             0.000000
# review_value                      9.589041
# n_user_reviews                   89.726027
# reviewer_name                     0.000000
# reviewer_country                  0.000000
# date_of_review                    0.000000
# review_text                       0.000000
# aircraft                         89.726027
# traveller_type                   78.767123
# seat_type                        10.273973
# route                            78.767123
# date_flown                       78.767123
# seat_comfort_rating              32.876712
# cabin_staff_service_rating       32.876712
# food_and_beverages_rating        37.671233
# inflight_entertainment_rating    47.945205
# ground_service_rating            78.767123
# value_for_money_rating            9.589041
# recommendation                    0.000000
# dtype: float64

# %% [markdown]
# It seems that most reviews are missing the majority of `n_user_reviews`, `aircraft`, `traveller_type`, `route`, `date_flown`, and `ground_service_rating`.
#
# Trying to infer things from these columns will likely be not very useful as we only have 146 samples to use.

# %% [markdown]
# #### Verifying that all reviews are in original dataset

# %%
# load the original dataset

f = open("../../data/given_4U_reviews.txt")
orig_reviews = f.read()
f.close()

# %%
# check to make sure that all our extracted reviews are in the original dataset
#
# note that the last review in the given reviews was from 16th October 2015, 
# so there will be some extra reviews
#
# print the date and title of the review if it is not found in the original reviews

for count, review in enumerate(reviews["review_text"]):
    if review not in orig_reviews:
        print(reviews["date_of_review"][count]," : ", reviews["title"][count],"\n")
# Out:
# 2019-07-01 00:00:00  :  "Seat was fine with enough legroom"
#
# 2019-07-01 00:00:00  :  "crew were smiling and good"
#
# 2017-01-04 00:00:00  :  "only two agents available"
#
# 2016-09-13 00:00:00  :  "good flight and friendly staff"
#
# 2016-08-16 00:00:00  :  "never been treated as badly"
#
# 2016-05-11 00:00:00  :  "very cramped"
#
# 2016-04-11 00:00:00  :  "staff were friendly"
#
# 2016-02-08 00:00:00  :  PLEASE REFER TO EUROWINGS
#
# 2016-01-23 00:00:00  :  "great value for money"
#
# 2016-01-21 00:00:00  :  "pay very little money"
#
# 2015-12-22 00:00:00  :  "friendly and professional"
#
# 2015-12-07 00:00:00  :  "little choice of airline"
#
# 2015-11-16 00:00:00  :  "were very satisfied"
#
# 2015-11-03 00:00:00  :  "no info or staff"
#
# 2015-10-27 00:00:00  :  "cabin crew were very friendly"
#
# 2015-10-21 00:00:00  :  "professional cabin crew"
#
# 2015-10-21 00:00:00  :  "friendly cabin staff"
#
# 2015-10-15 00:00:00  :  "impressed with Germanwings"
#
# 2015-09-14 00:00:00  :  "I don't get why Germanwings is always late"
#
# 2015-09-09 00:00:00  :  "vowing never to book Germanwings again"
#
# 2015-09-09 00:00:00  :  "staff friendly - food terrible"
#
# 2015-09-06 00:00:00  :  "no explanations, no offers of help"
#
# 2015-08-15 00:00:00  :  Germanwings customer review
#
# 2015-06-19 00:00:00  :  Germanwings customer review

# %% [markdown]
# Most of these reviews are after 16th October 2016, so we know that it is mostly good.  But there are 7 reviews at the bottom that should be showing up as in the scraped dataset.  Let's look at the `2015-09-09 00:00:00  :  "staff friendly - food terrible"` entry.

# %%
# the original review copied from the given text file
review_from_given_txt = """"staff friendly - food terrible"
Jay Martin (Germany) 9th September 2015
7
Easy Check-In at Düsseldorf. The Germanwings flight was on time. Seats good for a low-cost airline. The food was terrible and expensive. The normal Ticket price excludes luggage, and for including luggage check-in you have to pay extra money. Staff were friendly.
Type Of Traveller	Solo Leisure
Cabin Flown	Economy
Route	Düsseldorf to London
Date Flown	August 2015
Seat Comfort	12345
Cabin Staff Service	12345
Food & Beverages	12345
Inflight Entertainment	12345
Ground Service	12345
Wifi & Connectivity	12345
Value For Money	12345
Recommended	yes"""
print(review_from_given_txt)
# Out:
# "staff friendly - food terrible"
# Jay Martin (Germany) 9th September 2015
# 7
# Easy Check-In at Düsseldorf. The Germanwings flight was on time. Seats good for a low-cost airline. The food was terrible and expensive. The normal Ticket price excludes luggage, and for including luggage check-in you have to pay extra money. Staff were friendly.
# Type Of Traveller	Solo Leisure
# Cabin Flown	Economy
# Route	Düsseldorf to London
# Date Flown	August 2015
# Seat Comfort	12345
# Cabin Staff Service	12345
# Food & Beverages	12345
# Inflight Entertainment	12345
# Ground Service	12345
# Wifi & Connectivity	12345
# Value For Money	12345
# Recommended	yes

# %%
# get the review from the scraped dataset
reviews["review_text"][reviews["title"].str.contains("staff friendly - food terrible")].values[0]
# Out:
# 'Easy Check-In at Düsseldorf. The Germanwings flight was on  time. Seats good for a low-cost airline. The food was terrible and expensive. The normal Ticket price excludes luggage, and for including luggage check-in you have to pay extra money. Staff were friendly.'

# %% [markdown]
# The two reviews are identical, but there is likely some hidden formatting messing things up.
#
# I verified that the other 6 reviews were also the same, and with that am confident that my dataset has the same content with additional information compared to the provided one.

# %% [markdown]
# #### Date Differences

# %% [markdown]
# Check to see what the difference in between the date flown and date reviewed to see if the review date is close enough to be used for date flown.

# %%
# figure out the time difference in days, removing any NA values
time_difference = (reviews["date_of_review"] - reviews["date_flown"]).dt.days.dropna().values

# %%
sns.distplot(time_difference, kde = False)
plt.title("Difference Between Date Reviewed\n and Date Flown in Days")
# Out:
# Text(0.5, 1.0, 'Difference Between Date Reviewed\n and Date Flown in Days')

# %%
np.quantile(time_difference, 0.8)
# Out:
# 50.0

# %% [markdown]
# It seems that 80% of reviews are posted within 50 days, and since we are missing most of the `date_flown` columns, I'll assume that the date flown is close to the date reviewed.

# %% [markdown]
# #### Data Cleaning

# %% [markdown]
# Some data cleaning is now necessary.  Here is the plan:
#
# - Isolate the reviewer country
# - *Split `route` into origin and destination* (not crucial due to large amount of NaNs)
